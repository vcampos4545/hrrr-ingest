# %% [markdown]
# # Downloading and maniupulating grib data from AWS Open Data Registry

# %%
import requests

url = "https://noaa-hrrr-bdp-pds.s3.amazonaws.com/hrrr.20250424/conus/hrrr.t06z.wrfsfcf00.grib2"
r = requests.get(url, stream=True)

with open("local_file.grib2", "wb") as f:
    for chunk in r.iter_content(chunk_size=8192): # 8192 bytes (8 KB) is good balance for RAM/speed
        f.write(chunk)

# %%
import pygrib

grbs = pygrib.open("local_file.grib2")

# List all messages
for grb in grbs:
    print(grb)   # prints metadata like name, level, units
# Out:
# 1:Maximum/Composite radar reflectivity:dB (instant):lambert:atmosphere:level 0 -:fcst time 0 hrs:from 202504240600
# 2:3:3 (instant):lambert:cloudTop:level 0:fcst time 0 hrs:from 202504240600
# 3:201:201 (instant):lambert:atmosphere:level 0 -:fcst time 0 hrs:from 202504240600
# 4:Vertically-integrated liquid:kg m**-1 (instant):lambert:atmosphere:level 0 -:fcst time 0 hrs:from 202504240600
# 5:Visibility:m (instant):lambert:surface:level 0:fcst time 0 hrs:from 202504240600
# 6:Derived radar reflectivity:dB (instant):lambert:heightAboveGround:level 1000 m:fcst time 0 hrs:from 202504240600
# 7:Derived radar reflectivity:dB (instant):lambert:heightAboveGround:level 4000 m:fcst time 0 hrs:from 202504240600
# 8:Derived radar reflectivity:dB (instant):lambert:isothermal:level 263 K:fcst time 0 hrs:from 202504240600
# 9:Wind speed (gust):m s**-1 (instant):lambert:surface:level 0:fcst time 0 hrs:from 202504240600
# 10:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 25000 Pa:fcst time 0 hrs:from 202504240600
# 11:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 25000 Pa:fcst time 0 hrs:from 202504240600
# 12:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 30000 Pa:fcst time 0 hrs:from 202504240600
# 13:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 30000 Pa:fcst time 0 hrs:from 202504240600
# 14:Geopotential height:gpm (instant):lambert:isobaricInhPa:level 50000 Pa:fcst time 0 hrs:from 202504240600
# 15:Temperature:K (instant):lambert:isobaricInhPa:level 50000 Pa:fcst time 0 hrs:from 202504240600
# 16:Dew point temperature:K (instant):lambert:isobaricInhPa:level 50000 Pa:fcst time 0 hrs:from 202504240600
# 17:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 50000 Pa:fcst time 0 hrs:from 202504240600
# 18:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 50000 Pa:fcst time 0 hrs:from 202504240600
# 19:Geopotential height:gpm (instant):lambert:isobaricInhPa:level 70000 Pa:fcst time 0 hrs:from 202504240600
# 20:Temperature:K (instant):lambert:isobaricInhPa:level 70000 Pa:fcst time 0 hrs:from 202504240600
# 21:Dew point temperature:K (instant):lambert:isobaricInhPa:level 70000 Pa:fcst time 0 hrs:from 202504240600
# 22:Geometric vertical velocity:m s**-1 (instant):lambert:isobaricInhPa:level 70000 Pa:fcst time 0 hrs:from 202504240600
# 23:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 70000 Pa:fcst time 0 hrs:from 202504240600
# 24:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 70000 Pa:fcst time 0 hrs:from 202504240600
# 25:Geopotential height:gpm (instant):lambert:isobaricInhPa:level 85000 Pa:fcst time 0 hrs:from 202504240600
# 26:Temperature:K (instant):lambert:isobaricInhPa:level 85000 Pa:fcst time 0 hrs:from 202504240600
# 27:Dew point temperature:K (instant):lambert:isobaricInhPa:level 85000 Pa:fcst time 0 hrs:from 202504240600
# 28:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 85000 Pa:fcst time 0 hrs:from 202504240600
# 29:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 85000 Pa:fcst time 0 hrs:from 202504240600
# 30:Temperature:K (instant):lambert:isobaricInhPa:level 92500 Pa:fcst time 0 hrs:from 202504240600
# 31:Dew point temperature:K (instant):lambert:isobaricInhPa:level 92500 Pa:fcst time 0 hrs:from 202504240600
# 32:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 92500 Pa:fcst time 0 hrs:from 202504240600
# 33:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 92500 Pa:fcst time 0 hrs:from 202504240600
# 34:Temperature:K (instant):lambert:isobaricInhPa:level 100000 Pa:fcst time 0 hrs:from 202504240600
# 35:Dew point temperature:K (instant):lambert:isobaricInhPa:level 100000 Pa:fcst time 0 hrs:from 202504240600
# 36:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 100000 Pa:fcst time 0 hrs:from 202504240600
# 37:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 100000 Pa:fcst time 0 hrs:from 202504240600
# 38:220:220 (max):lambert:pressureFromGroundLayer:levels 10000-100000 Pa:fcst time 0 hrs (max):from 202504240600
# 39:221:221 (max):lambert:pressureFromGroundLayer:levels 10000-100000 Pa:fcst time 0 hrs (max):from 202504240600
# 40:Geometric vertical velocity:m s**-1 (avg):lambert:sigmaLayer:levels 0.5-0.8 sigma value:fcst time 0 hrs (avg):from 202504240600
# 41:MSLP (MAPS System Reduction):Pa (instant):lambert:meanSea:level 0:fcst time 0 hrs:from 202504240600
# 42:Geopotential height:gpm (instant):lambert:isobaricInhPa:level 100000 Pa:fcst time 0 hrs:from 202504240600
# 43:198:198 (max):lambert:heightAboveGround:level 1000 m:fcst time 0 hrs (max):from 202504240600
# 44:Derived radar reflectivity:dB (max):lambert:isothermal:level 263 K:fcst time 0 hrs (max):from 202504240600
# 45:199:199 (max):lambert:heightAboveGroundLayer:levels 5000-2000 m:fcst time 0 hrs (max):from 202504240600
# 46:200:200 (min):lambert:heightAboveGroundLayer:levels 5000-2000 m:fcst time 0 hrs (min):from 202504240600
# 47:199:199 (max):lambert:heightAboveGroundLayer:levels 2000-0 m:fcst time 0 hrs (max):from 202504240600
# 48:200:200 (min):lambert:heightAboveGroundLayer:levels 2000-0 m:fcst time 0 hrs (min):from 202504240600
# 49:199:199 (max):lambert:heightAboveGroundLayer:levels 3000-0 m:fcst time 0 hrs (max):from 202504240600
# 50:200:200 (min):lambert:heightAboveGroundLayer:levels 3000-0 m:fcst time 0 hrs (min):from 202504240600
# 51:Vorticity (relative):s**-1 (max):lambert:heightAboveGroundLayer:levels 2000-0 m:fcst time 0 hrs (max):from 202504240600
# 52:Vorticity (relative):s**-1 (max):lambert:heightAboveGroundLayer:levels 1000-0 m:fcst time 0 hrs (max):from 202504240600
# 53:Hail:m (max):lambert:atmosphere:level 0 -:fcst time 0 hrs (max):from 202504240600
# 54:Hail:m (max):lambert:sigma:level 0.1 sigma value:fcst time 0 hrs (max):from 202504240600
# 55:Hail:m (max):lambert:surface:level 0:fcst time 0 hrs (max):from 202504240600
# 56:74:74 (max):lambert:atmosphereSingleLayer:level 0 considered as a single layer:fcst time 0 hrs (max):from 202504240600
# 57:0:0 (instant):lambert:heightAboveGround:level 1 m:fcst time 0 hrs:from 202504240600
# 58:0:0 (instant):lambert:heightAboveGround:level 2 m:fcst time 0 hrs:from 202504240600
# 59:Lightning:dimensionless (instant):lambert:atmosphere:level 0 -:fcst time 0 hrs:from 202504240600
# 60:U component of wind:m s**-1 (instant):lambert:heightAboveGround:level 80 m:fcst time 0 hrs:from 202504240600
# 61:V component of wind:m s**-1 (instant):lambert:heightAboveGround:level 80 m:fcst time 0 hrs:from 202504240600
# 62:Surface pressure:Pa (instant):lambert:surface:level 0:fcst time 0 hrs:from 202504240600
# 63:Orography:m (instant):lambert:surface:level 0:fcst time 0 hrs:from 202504240600
# 64:Temperature:K (instant):lambert:surface:level 0:fcst time 0 hrs:from 202504240600
# 65:Total snowfall:m (accum):lambert:surface:level 0:fcst time 0 hrs (accum):from 202504240600
# 66:Moisture availability:% (instant):lambert:depthBelowLand:level 0 m:fcst time 0 hrs:from 202504240600
# 67:Plant canopy surface water:kg m**-2 (instant):lambert:surface:level 0:fcst time 0 hrs:from 202504240600
# 68:Water equivalent of accumulated snow depth (deprecated):kg m**-2 (instant):lambert:surface:level 0:fcst time 0 hrs:from 202504240600
# 69:Snow cover:% (instant):lambert:surface:level 0:fcst time 0 hrs:from 202504240600
# 70:Snow depth:m (instant):lambert:surface:level 0:fcst time 0 hrs:from 202504240600
# 71:2 metre temperature:K (instant):lambert:heightAboveGround:level 2 m:fcst time 0 hrs:from 202504240600
# 72:Potential temperature:K (instant):lambert:heightAboveGround:level 2 m:fcst time 0 hrs:from 202504240600
# 73:2 metre specific humidity:kg kg**-1 (instant):lambert:heightAboveGround:level 2 m:fcst time 0 hrs:from 202504240600
# 74:2 metre dewpoint temperature:K (instant):lambert:heightAboveGround:level 2 m:fcst time 0 hrs:from 202504240600
# 75:2 metre relative humidity:% (instant):lambert:heightAboveGround:level 2 m:fcst time 0 hrs:from 202504240600
# 76:Mass density:kg m**-3 (instant):lambert:heightAboveGround:level 8 m:fcst time 0 hrs:from 202504240600
# 77:10 metre U wind component:m s**-1 (instant):lambert:heightAboveGround:level 10 m:fcst time 0 hrs:from 202504240600
# 78:10 metre V wind component:m s**-1 (instant):lambert:heightAboveGround:level 10 m:fcst time 0 hrs:from 202504240600
# 79:10 metre wind speed:m s**-1 (max):lambert:heightAboveGround:level 10 m:fcst time 0 hrs (max):from 202504240600
# 80:222:222 (max):lambert:heightAboveGround:level 10 m:fcst time 0 hrs (max):from 202504240600
# 81:223:223 (max):lambert:heightAboveGround:level 10 m:fcst time 0 hrs (max):from 202504240600
# 82:Percent frozen precipitation:% (instant):lambert:surface:level 0:fcst time 0 hrs:from 202504240600
# 83:Precipitation rate:kg m**-2 s**-1 (instant):lambert:surface:level 0:fcst time 0 hrs:from 202504240600
# 84:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0 hrs (accum):from 202504240600
# 85:Water equivalent of accumulated snow depth (deprecated):kg m**-2 (accum):lambert:surface:level 0:fcst time 0 hrs (accum):from 202504240600
# 86:227:227 (accum):lambert:surface:level 0:fcst time 0 hrs (accum):from 202504240600
# 87:Freezing Rain:kg m**-2 (accum):lambert:surface:level 0:fcst time 0 hrs (accum):from 202504240600
# 88:Storm surface runoff:kg m**-2 (accum):lambert:surface:level 0:fcst time 0 hrs (accum):from 202504240600
# 89:Baseflow-groundwater runoff:kg m**-2 (accum):lambert:surface:level 0:fcst time 0 hrs (accum):from 202504240600
# 90:Categorical snow:(Code table 4.222) (instant):lambert:surface:level 0:fcst time 0 hrs:from 202504240600
# 91:Categorical ice pellets:(Code table 4.222) (instant):lambert:surface:level 0:fcst time 0 hrs:from 202504240600
# 92:Categorical freezing rain:(Code table 4.222) (instant):lambert:surface:level 0:fcst time 0 hrs:from 202504240600
# 93:Categorical rain:(Code table 4.222) (instant):lambert:surface:level 0:fcst time 0 hrs:from 202504240600
# 94:Forecast surface roughness:m (instant):lambert:surface:level 0:fcst time 0 hrs:from 202504240600
# 95:Frictional velocity:m s**-1 (instant):lambert:surface:level 0:fcst time 0 hrs:from 202504240600
# 96:Instantaneous surface sensible heat flux:W m**-2 (instant):lambert:surface:level 0:fcst time 0 hrs:from 202504240600
# 97:Latent heat net flux:W m**-2 (instant):lambert:surface:level 0:fcst time 0 hrs:from 202504240600
# 98:Vegetation:% (instant):lambert:surface:level 0:fcst time 0 hrs:from 202504240600
# 99:231:231 (instant):lambert:surface:level 0:fcst time 0 hrs:from 202504240600
# 100:232:232 (instant):lambert:surface:level 0:fcst time 0 hrs:from 202504240600
# 101:Leaf Area Index:Numeric (instant):lambert:surface:level 0:fcst time 0 hrs:from 202504240600
# 102:Ground heat flux:W m**-2 (instant):lambert:surface:level 0:fcst time 0 hrs:from 202504240600
# 103:Vegetation Type:Integer(0-13) (instant):lambert:surface:level 0:fcst time 0 hrs:from 202504240600
# 104:Surface lifted index:K (instant):lambert:isobaricLayer:levels 50000-100000 Pa:fcst time 0 hrs:from 202504240600
# 105:Convective available potential energy:J kg**-1 (instant):lambert:surface:level 0:fcst time 0 hrs:from 202504240600
# 106:Convective inhibition:J kg**-1 (instant):lambert:surface:level 0:fcst time 0 hrs:from 202504240600
# 107:Precipitable water:kg m**-2 (instant):lambert:atmosphereSingleLayer:level 0 considered as a single layer:fcst time 0 hrs:from 202504240600
# 108:Aerosol optical depth:Numeric (instant):lambert:atmosphereSingleLayer:level 0 considered as a single layer:fcst time 0 hrs:from 202504240600
# 109:Total column:integrated mass density (instant):lambert:atmosphereSingleLayer:level 0 considered as a single layer:fcst time 0 hrs:from 202504240600
# 110:69:69 (instant):lambert:atmosphere:level 0 -:fcst time 0 hrs:from 202504240600
# 111:70:70 (instant):lambert:atmosphere:level 0 -:fcst time 0 hrs:from 202504240600
# 112:Total Cloud Cover:% (instant):lambert:boundaryLayerCloudLayer:level 0:fcst time 0 hrs:from 202504240600
# 113:Low cloud cover:% (instant):lambert:lowCloudLayer:level 0:fcst time 0 hrs:from 202504240600
# 114:Medium cloud cover:% (instant):lambert:middleCloudLayer:level 0:fcst time 0 hrs:from 202504240600
# 115:High cloud cover:% (instant):lambert:highCloudLayer:level 0:fcst time 0 hrs:from 202504240600
# 116:Total Cloud Cover:% (instant):lambert:atmosphere:level 0 -:fcst time 0 hrs:from 202504240600
# 117:Geopotential height:gpm (instant):lambert:cloudCeiling:level 0:fcst time 0 hrs:from 202504240600
# 118:Geopotential height:gpm (instant):lambert:cloudBase:level 0:fcst time 0 hrs:from 202504240600
# 119:Pressure at cloud base:Pa (instant):lambert:cloudBase:level 0:fcst time 0 hrs:from 202504240600
# 120:Pressure:Pa (instant):lambert:cloudTop:level 0:fcst time 0 hrs:from 202504240600
# 121:Geopotential height:gpm (instant):lambert:cloudTop:level 0:fcst time 0 hrs:from 202504240600
# 122:Upward long-wave radiation flux:W m**-2 (instant):lambert:nominalTop:level 0:fcst time 0 hrs:from 202504240600
# 123:Downward short-wave radiation flux:W m**-2 (instant):lambert:surface:level 0:fcst time 0 hrs:from 202504240600
# 124:Downward long-wave radiation flux:W m**-2 (instant):lambert:surface:level 0:fcst time 0 hrs:from 202504240600
# 125:Upward short-wave radiation flux:W m**-2 (instant):lambert:surface:level 0:fcst time 0 hrs:from 202504240600
# 126:Upward long-wave radiation flux:W m**-2 (instant):lambert:surface:level 0:fcst time 0 hrs:from 202504240600
# 127:Cloud Forcing Net Solar Flux:W m**-2 (instant):lambert:surface:level 0:fcst time 0 hrs:from 202504240600
# 128:Visible Beam Downward Solar Flux:W m**-2 (instant):lambert:surface:level 0:fcst time 0 hrs:from 202504240600
# 129:Visible Diffuse Downward Solar Flux:W m**-2 (instant):lambert:surface:level 0:fcst time 0 hrs:from 202504240600
# 130:Upward short-wave radiation flux:W m**-2 (instant):lambert:nominalTop:level 0:fcst time 0 hrs:from 202504240600
# 131:Storm relative helicity:m**2 s**-2 (instant):lambert:heightAboveGroundLayer:levels 3000-0 m:fcst time 0 hrs:from 202504240600
# 132:Storm relative helicity:m**2 s**-2 (instant):lambert:heightAboveGroundLayer:levels 1000-0 m:fcst time 0 hrs:from 202504240600
# 133:U-component storm motion:m s**-1 (instant):lambert:heightAboveGroundLayer:levels 0-6000 m:fcst time 0 hrs:from 202504240600
# 134:V-component storm motion:m s**-1 (instant):lambert:heightAboveGroundLayer:levels 0-6000 m:fcst time 0 hrs:from 202504240600
# 135:Vertical u-component shear:s**-1 (instant):lambert:heightAboveGroundLayer:levels 0-1000 m:fcst time 0 hrs:from 202504240600
# 136:Vertical v-component shear:s**-1 (instant):lambert:heightAboveGroundLayer:levels 0-1000 m:fcst time 0 hrs:from 202504240600
# 137:Vertical u-component shear:s**-1 (instant):lambert:heightAboveGroundLayer:levels 0-6000 m:fcst time 0 hrs:from 202504240600
# 138:Vertical v-component shear:s**-1 (instant):lambert:heightAboveGroundLayer:levels 0-6000 m:fcst time 0 hrs:from 202504240600
# 139:Geopotential height:gpm (instant):lambert:isothermZero:level 0:fcst time 0 hrs:from 202504240600
# 140:Relative humidity:% (instant):lambert:isothermZero:level 0:fcst time 0 hrs:from 202504240600
# 141:Pressure:Pa (instant):lambert:isothermZero:level 0:fcst time 0 hrs:from 202504240600
# 142:Geopotential height:gpm (instant):lambert:highestTroposphericFreezing:level 0:fcst time 0 hrs:from 202504240600
# 143:Relative humidity:% (instant):lambert:highestTroposphericFreezing:level 0:fcst time 0 hrs:from 202504240600
# 144:Pressure:Pa (instant):lambert:highestTroposphericFreezing:level 0:fcst time 0 hrs:from 202504240600
# 145:Geopotential height:gpm (instant):lambert:isothermal:level 263 K:fcst time 0 hrs:from 202504240600
# 146:Geopotential height:gpm (instant):lambert:isothermal:level 253 K:fcst time 0 hrs:from 202504240600
# 147:Best (4-layer) lifted index:K (instant):lambert:pressureFromGroundLayer:levels 18000-0 Pa:fcst time 0 hrs:from 202504240600
# 148:Convective available potential energy:J kg**-1 (instant):lambert:pressureFromGroundLayer:levels 18000-0 Pa:fcst time 0 hrs:from 202504240600
# 149:Convective inhibition:J kg**-1 (instant):lambert:pressureFromGroundLayer:levels 18000-0 Pa:fcst time 0 hrs:from 202504240600
# 150:Boundary layer height:m (instant):lambert:surface:level 0:fcst time 0 hrs:from 202504240600
# 151:Geopotential height:gpm (instant):lambert:adiabaticCondensation:level 0:fcst time 0 hrs:from 202504240600
# 152:Convective available potential energy:J kg**-1 (instant):lambert:pressureFromGroundLayer:levels 9000-0 Pa:fcst time 0 hrs:from 202504240600
# 153:Convective inhibition:J kg**-1 (instant):lambert:pressureFromGroundLayer:levels 9000-0 Pa:fcst time 0 hrs:from 202504240600
# 154:Convective available potential energy:J kg**-1 (instant):lambert:pressureFromGroundLayer:levels 25500-0 Pa:fcst time 0 hrs:from 202504240600
# 155:Convective inhibition:J kg**-1 (instant):lambert:pressureFromGroundLayer:levels 25500-0 Pa:fcst time 0 hrs:from 202504240600
# 156:Geopotential height:gpm (instant):lambert:equilibrium:level 0:fcst time 0 hrs:from 202504240600
# 157:Pressure of level from which parcel was lifted:Pa (instant):lambert:pressureFromGroundLayer:levels 25500-0 Pa:fcst time 0 hrs:from 202504240600
# 158:Convective available potential energy:J kg**-1 (instant):lambert:heightAboveGroundLayer:levels 0-3000 m:fcst time 0 hrs:from 202504240600
# 159:Geopotential height:gpm (instant):lambert:freeConvection:level 0 LFC:fcst time 0 hrs:from 202504240600
# 160:204:204 (instant):lambert:surface:level 0:fcst time 0 hrs:from 202504240600
# 161:206:206 (instant):lambert:heightAboveGroundLayer:levels 0-500 m:fcst time 0 hrs:from 202504240600
# 162:Layer Thickness:m (instant):lambert:unknown:levels 261-256 K:fcst time 0 hrs:from 202504240600
# 163:205:205 (instant):lambert:heightAboveGroundLayer:levels 0-3000 m:fcst time 0 hrs:from 202504240600
# 164:242:242 (instant):lambert:atmosphere:level 0 -:fcst time 0 hrs:from 202504240600
# 165:Land-sea mask:(0 - 1) (instant):lambert:surface:level 0:fcst time 0 hrs:from 202504240600
# 166:Sea ice area fraction:(0 - 1) (instant):lambert:surface:level 0:fcst time 0 hrs:from 202504240600
# 167:Simulated Brightness Temperature for GOES 12, Channel 3:K (instant):lambert:nominalTop:level 0:fcst time 0 hrs:from 202504240600
# 168:Simulated Brightness Temperature for GOES 12, Channel 4:K (instant):lambert:nominalTop:level 0:fcst time 0 hrs:from 202504240600
# 169:Simulated Brightness Temperature for GOES 11, Channel 3:K (instant):lambert:nominalTop:level 0:fcst time 0 hrs:from 202504240600
# 170:Simulated Brightness Temperature for GOES 11, Channel 4:K (instant):lambert:nominalTop:level 0:fcst time 0 hrs:from 202504240600

# %%
# Example: nearest grid point to 40N, -105W (Boulder, CO)
import numpy as np

lats, lons = grb.latlons()
dist = (lats-40)**2 + (lons+105)**2
i, j = np.unravel_index(dist.argmin(), dist.shape)

# %%
vars_levels = {
    "Surface pressure": {},
    "Forecast surface roughness": {},
    "Visible Beam Downward Solar Flux": {},
    "Visible Diffuse Downward Solar Flux": {},
    "2 metre temperature": {},
    "2 metre dewpoint temperature": {},
    "2 metre relative humidity": {},
    "10 metre U wind component": {},  # name includes 10m
    "10 metre V wind component": {},  # name includes 10m
    "U component of wind": {"level": 80},
    "V component of wind": {"level": 80},
}

for var, lvl_args in vars_levels.items():
    try:
        grb = grbs.select(name=var, **lvl_args)[0]
        data = grb.values
        print(f"{var}: {lvl_args}", data[i, j])
    except Exception as e:
        print(f"Error parsing {var}:", e)
# Out:
# Surface pressure: {} 83730.0
# Forecast surface roughness: {} 0.0821
# Visible Beam Downward Solar Flux: {} 0.0
# Visible Diffuse Downward Solar Flux: {} 0.0
# 2 metre temperature: {} 284.3097229003906
# 2 metre dewpoint temperature: {} 277.72605895996094
# 2 metre relative humidity: {} 64.3
# 10 metre U wind component: {} -0.05168724060058594
# 10 metre V wind component: {} -2.5212268829345703
# U component of wind: {'level': 80} -0.03038787841796875
# V component of wind: {'level': 80} -2.567718505859375
